# %% [raw]
# ---
# layout: post
# title: UESL 3.1 Homework
# permalink: /homework/3-1/
# categories: [Python]
# author: alt ct
# ---

# %% [markdown]
# # 3.1 Variables and Assignments — Homework Submission

# %% [markdown]
# ## Popcorn Hack — Checkpoint challenge

# %%
# CODE_RUNNER: UESL 3.1 Popcorn - Keep the checkpoint
stars = 8
checkpoint_stars = stars
stars = stars + 4
print(stars)             # 12
print(checkpoint_stars)  # 8

# %% [markdown]
# ## Homework Hack — UESL star counter

# %%
# CODE_RUNNER: UESL 3.1 Homework - Build the star counter
game_name = "UESL Nightfall Sprint"
reduced_motion = True

level_one_stars = 12
level_two_stars = 18
level_three_stars = 10
total_stars = level_one_stars + level_two_stars + level_three_stars

print(game_name)
print(reduced_motion)
print(total_stars)  # original/stored total: 40

level_two_stars = level_two_stars + 5
print(total_stars)  # still 40 - not yet recalculated

total_stars = level_one_stars + level_two_stars + level_three_stars
print(total_stars)  # updated total: 45
